# %% [markdown]
# <a href="https://colab.research.google.com/github/SyedMuhammadHunain/ai-engineering-from-scratch-course/blob/main/Second.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import numpy as np
# Out:
# 5.07 μs ± 67.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit x = [random.randint(0, 99999) for _ in range(10)]
# %timeit np.random.randn(10000)
# Out:
# 5.72 μs ± 462 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 238 μs ± 6.33 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
